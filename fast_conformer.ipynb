# %%
# %cd ASR_for_egyptian_dialect
# Out:
# [WinError 2] The system cannot find the file specified: 'ASR_for_egyptian_dialect'
# c:\Users\Patrickn\Jupyter_notebooks\Graduation

# %%
# import signal
# if not hasattr(signal, "SIGKILL"):
#     signal.SIGKILL = signal.SIGTERM

# %%
import nemo
import torch

print(f"Nemo version: {nemo.__version__}")
print(f"PyTorch version: {torch.__version__}")
# Out:
# Nemo version: 2.1.0rc0
# PyTorch version: 2.5.1+cpu

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DAB6-B0D3
#
#  Directory of c:\Users\Patrickn\Jupyter_notebooks\Graduation
#
# 11/26/2024  06:04 PM    <DIR>          .
# 11/26/2024  05:13 PM    <DIR>          ..
# 11/24/2024  03:02 PM             4,870 CharacterMovement.cs
# 11/26/2024  04:07 PM            83,634 fast_conformer.ipynb
# 11/26/2024  06:26 PM    <DIR>          klaam
# 11/26/2024  08:19 PM             8,505 klaam.ipynb
# 11/25/2024  06:59 PM    <DIR>          Models
# 11/17/2024  03:15 PM         1,764,044 recorded_audio.wav
# 11/24/2024  09:16 PM    <DIR>          repo
# 11/17/2024  03:23 PM             5,775 speech_to_text.ipynb
# 11/24/2024  03:02 PM             2,258 webscraping.py
#                6 File(s)      1,869,086 bytes
#                5 Dir(s)  444,747,436,032 bytes free

# %%
import torch
import librosa
import nemo.collections.asr as nemo_asr
from ruamel.yaml import YAML
from omegaconf import OmegaConf

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ASR model
def load_asr_model(ckpt_path):
    config_path = 'repo/ASR_for_egyptian_dialect/configs/FC-transducer-inference.yaml'
    yaml = YAML(typ='safe')
    with open(config_path) as f:
        params = yaml.load(f)
    params['model'].pop('test_ds', None)
    conf = OmegaConf.create(params)

    model = nemo_asr.models.EncDecRNNTBPEModel(cfg=conf['model']).to(device)
    model.load_state_dict(torch.load(ckpt_path)['state_dict'])
    model.eval()
    return model

# Function to load audio using librosa
def load_audio(audio_path):
    audio, sr = librosa.load(audio_path, sr=16000)  # Ensure correct sample rate
    return audio, sr

# Inference function
def infer(model, audio):
    return model.transcribe([audio])

# Path to your specific WAV file
audio_path = "recorded_audio.wav"

# Load the ASR model
print("Loading ASR model...")
asr_model = load_asr_model("Models/asr_model.ckpt")

# Load the audio using librosa
print(f"Loading audio from {audio_path}...")
audio, sr = load_audio(audio_path)

# Perform inference
print("Starting inference...")
with torch.no_grad():
    transcript = infer(model=asr_model, audio=audio)

# Print or save the result
print(f"Transcript: {transcript[0]}")

# %%
# !pip install git+https://github.com/NVIDIA/NeMo.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/NVIDIA/NeMo.git
#   Cloning https://github.com/NVIDIA/NeMo.git to c:\users\patrickn\appdata\local\temp\pip-req-build-7a1bo0h3
#   Resolved https://github.com/NVIDIA/NeMo.git to commit 5d97b70cde8ff2d6232addcbe6d38eaa127aa284
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting huggingface_hub>=0.24 (from nemo-toolkit==2.1.0rc0)
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Collecting numba (from nemo-toolkit==2.1.0rc0)
#   Using cached numba-0.60.0-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting numpy>=1.22 (from nemo-toolkit==2.1.0rc0)
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting onnx>=1.7.0 (from nemo-toolkit==2.1.0rc0)
#   Using cached onnx-1.17.0-cp310-cp310-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda\envs\fast_conformer\lib\site-packages (from nemo-toolkit==2.1.0rc0) (2.9.0)
# Collecting ruamel.yaml (from nemo-toolkit==2.1.0rc0)
#   Using cached ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting scikit-learn (from nemo-toolkit==2.1.0rc0)
#   Using cached scikit_learn-1.5.2-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: setuptools>=70.0.0 in c:\programdata\anaconda\envs\fast_conformer\lib\site-packages (from nemo-toolkit==2.1.0rc0) (75.1.0)
# Collecting tensorboard (from nemo-toolkit==2.1.0rc0)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting text-unidecode (from nemo-toolkit==2.1.0rc0)
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting torch (from nemo-toolkit==2.1.0rc0)
#   Using cached torch-2.5.1-cp310-cp310-win_amd64.whl.metadata (28 kB)
# Collecting tqdm>=4.41.0 (from nemo-toolkit==2.1.0rc0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting wget (from nemo-toolkit==2.1.0rc0)
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting wrapt (from nemo-toolkit==2.1.0rc0)
#   Using cached wrapt-1.17.0-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting filelock (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0)
#   Using cached fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (6.0.1)
# Requirement already satisfied: requests in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (4.12.2)
# Collecting protobuf>=3.20.2 (from onnx>=1.7.0->nemo-toolkit==2.1.0rc0)
#   Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: colorama in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from tqdm>=4.41.0->nemo-toolkit==2.1.0rc0) (0.4.6)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->nemo-toolkit==2.1.0rc0)
#   Downloading llvmlite-0.43.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting numpy>=1.22 (from nemo-toolkit==2.1.0rc0)
#   Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: six>=1.5 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from python-dateutil->nemo-toolkit==2.1.0rc0) (1.16.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->nemo-toolkit==2.1.0rc0)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Collecting scipy>=1.6.0 (from scikit-learn->nemo-toolkit==2.1.0rc0)
#   Using cached scipy-1.14.1-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->nemo-toolkit==2.1.0rc0)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->nemo-toolkit==2.1.0rc0)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting absl-py>=0.4 (from tensorboard->nemo-toolkit==2.1.0rc0)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->nemo-toolkit==2.1.0rc0)
#   Downloading grpcio-1.68.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting markdown>=2.6.8 (from tensorboard->nemo-toolkit==2.1.0rc0)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->nemo-toolkit==2.1.0rc0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->nemo-toolkit==2.1.0rc0)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting networkx (from torch->nemo-toolkit==2.1.0rc0)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from torch->nemo-toolkit==2.1.0rc0) (3.1.4)
# Collecting sympy==1.13.1 (from torch->nemo-toolkit==2.1.0rc0)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->nemo-toolkit==2.1.0rc0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from werkzeug>=1.0.1->tensorboard->nemo-toolkit==2.1.0rc0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from requests->huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from requests->huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from requests->huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\patrickn\appdata\roaming\python\python310\site-packages (from requests->huggingface_hub>=0.24->nemo-toolkit==2.1.0rc0) (2024.6.2)
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# Downloading onnx-1.17.0-cp310-cp310-win_amd64.whl (14.5 MB)
#    ---------------------------------------- 0.0/14.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.5 MB 1.4 MB/s eta 0:00:11
#    - -------------------------------------- 0.5/14.5 MB 1.4 MB/s eta 0:00:11
#    -- ------------------------------------- 0.8/14.5 MB 882.6 kB/s eta 0:00:16
#    -- ------------------------------------- 1.0/14.5 MB 1.0 MB/s eta 0:00:13
#    --- ------------------------------------ 1.3/14.5 MB 1.1 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/14.5 MB 1.2 MB/s eta 0:00:11
#    ----- ---------------------------------- 1.8/14.5 MB 1.1 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.1/14.5 MB 1.2 MB/s eta 0:00:11
#    ------- -------------------------------- 2.6/14.5 MB 1.3 MB/s eta 0:00:10
#    ------- -------------------------------- 2.9/14.5 MB 1.3 MB/s eta 0:00:09
#    --------- ------------------------------ 3.4/14.5 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.7/14.5 MB 1.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 3.9/14.5 MB 1.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.2/14.5 MB 1.5 MB/s eta 0:00:08
#    ------------ --------------------------- 4.5/14.5 MB 1.5 MB/s eta 0:00:07
#    ------------ --------------------------- 4.7/14.5 MB 1.4 MB/s eta 0:00:07
#    ------------- -------------------------- 5.0/14.5 MB 1.4 MB/s eta 0:00:07
#    -------------- ------------------------- 5.2/14.5 MB 1.4 MB/s eta 0:00:07
#    -------------- ------------------------- 5.2/14.5 MB 1.4 MB/s eta 0:00:07
#    --------------- ------------------------ 5.5/14.5 MB 1.3 MB/s eta 0:00:07
#    --------------- ------------------------ 5.5/14.5 MB 1.3 MB/s eta 0:00:07
#    --------------- ------------------------ 5.8/14.5 MB 1.2 MB/s eta 0:00:08
#    ----------------- ---------------------- 6.3/14.5 MB 1.3 MB/s eta 0:00:07
#    ------------------ --------------------- 6.6/14.5 MB 1.3 MB/s eta 0:00:07
#    ------------------ --------------------- 6.8/14.5 MB 1.3 MB/s eta 0:00:06
#    -------------------- ------------------- 7.3/14.5 MB 1.3 MB/s eta 0:00:06
#    -------------------- ------------------- 7.6/14.5 MB 1.3 MB/s eta 0:00:06
#    --------------------- ------------------ 7.9/14.5 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 8.4/14.5 MB 1.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 8.7/14.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 8.9/14.5 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 9.4/14.5 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 9.7/14.5 MB 1.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 10.2/14.5 MB 1.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 10.5/14.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 11.0/14.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------------- -------- 11.3/14.5 MB 1.5 MB/s eta 0:00:03
#    ------------------------------- -------- 11.5/14.5 MB 1.5 MB/s eta 0:00:03
#    -------------------------------- ------- 11.8/14.5 MB 1.5 MB/s eta 0:00:02
#    --------------------------------- ------ 12.1/14.5 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 12.6/14.5 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.8/14.5 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 13.1/14.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.4/14.5 MB 1.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.5 MB 1.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.9/14.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.5/14.5 MB 1.5 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading numba-0.60.0-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 1.5 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.7 MB/s eta 0:00:01
#    ------------------- -------------------- 1.3/2.7 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 1.7 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.9 MB 1.7 MB/s eta 0:00:10
#    - -------------------------------------- 0.8/15.9 MB 1.6 MB/s eta 0:00:10
#    --- ------------------------------------ 1.3/15.9 MB 1.6 MB/s eta 0:00:09
#    --- ------------------------------------ 1.6/15.9 MB 1.6 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.8/15.9 MB 1.7 MB/s eta 0:00:09
#    ----- ---------------------------------- 2.4/15.9 MB 1.7 MB/s eta 0:00:09
#    ------ --------------------------------- 2.6/15.9 MB 1.7 MB/s eta 0:00:08
#    ------- -------------------------------- 2.9/15.9 MB 1.7 MB/s eta 0:00:08
#    -------- ------------------------------- 3.4/15.9 MB 1.7 MB/s eta 0:00:08
#    --------- ------------------------------ 3.7/15.9 MB 1.7 MB/s eta 0:00:08
#    --------- ------------------------------ 3.9/15.9 MB 1.7 MB/s eta 0:00:08
#    ---------- ----------------------------- 4.2/15.9 MB 1.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 4.5/15.9 MB 1.6 MB/s eta 0:00:08
#    ------------ --------------------------- 5.0/15.9 MB 1.6 MB/s eta 0:00:07
#    ------------- -------------------------- 5.2/15.9 MB 1.6 MB/s eta 0:00:07
#    ------------- -------------------------- 5.2/15.9 MB 1.6 MB/s eta 0:00:07
#    ------------- -------------------------- 5.5/15.9 MB 1.5 MB/s eta 0:00:07
#    -------------- ------------------------- 5.8/15.9 MB 1.5 MB/s eta 0:00:07
#    --------------- ------------------------ 6.3/15.9 MB 1.5 MB/s eta 0:00:07
#    ---------------- ----------------------- 6.6/15.9 MB 1.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 6.8/15.9 MB 1.5 MB/s eta 0:00:06
#    ------------------ --------------------- 7.3/15.9 MB 1.6 MB/s eta 0:00:06
#    ------------------- -------------------- 7.6/15.9 MB 1.6 MB/s eta 0:00:06
#    ------------------- -------------------- 7.9/15.9 MB 1.6 MB/s eta 0:00:06
#    --------------------- ------------------ 8.4/15.9 MB 1.6 MB/s eta 0:00:05
#    --------------------- ------------------ 8.7/15.9 MB 1.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.2/15.9 MB 1.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 9.4/15.9 MB 1.6 MB/s eta 0:00:05
#    ------------------------ --------------- 9.7/15.9 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 10.2/15.9 MB 1.6 MB/s eta 0:00:04
#    -------------------------- ------------- 10.5/15.9 MB 1.6 MB/s eta 0:00:04
#    --------------------------- ------------ 11.0/15.9 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 11.3/15.9 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 11.8/15.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 12.1/15.9 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 12.3/15.9 MB 1.6 MB/s eta 0:00:03
#    -------------------------------- ------- 12.8/15.9 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 13.1/15.9 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 13.4/15.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 13.9/15.9 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.2/15.9 MB 1.7 MB/s eta 0:00:02
#    ------------------------------------ --- 14.4/15.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/15.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 14.7/15.9 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/15.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 1.6 MB/s eta 0:00:00
# Using cached ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
# Using cached scikit_learn-1.5.2-cp310-cp310-win_amd64.whl (11.0 MB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 2.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.5 MB 1.8 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.5 MB 1.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.5 MB 1.8 MB/s eta 0:00:03
#    --------------- ------------------------ 2.1/5.5 MB 1.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 2.4/5.5 MB 1.8 MB/s eta 0:00:02
#    -------------------- ------------------- 2.9/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.5 MB 1.8 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.5 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.8 MB/s eta 0:00:00
# Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading torch-2.5.1-cp310-cp310-win_amd64.whl (203.1 MB)
#    ---------------------------------------- 0.0/203.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/203.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/203.1 MB 1.7 MB/s eta 0:02:01
#    ---------------------------------------- 1.0/203.1 MB 1.9 MB/s eta 0:01:49
#    ---------------------------------------- 1.3/203.1 MB 1.8 MB/s eta 0:01:52
#    ---------------------------------------- 1.3/203.1 MB 1.8 MB/s eta 0:01:52
#    ---------------------------------------- 1.8/203.1 MB 1.6 MB/s eta 0:02:08
#    ---------------------------------------- 2.1/203.1 MB 1.6 MB/s eta 0:02:05
#     --------------------------------------- 2.6/203.1 MB 1.6 MB/s eta 0:02:03
#     --------------------------------------- 2.9/203.1 MB 1.7 MB/s eta 0:02:01
#     --------------------------------------- 3.4/203.1 MB 1.7 MB/s eta 0:02:00
#     --------------------------------------- 3.7/203.1 MB 1.7 MB/s eta 0:02:01
#     --------------------------------------- 3.9/203.1 MB 1.7 MB/s eta 0:02:01
MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 42.2/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 42.2/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 42.2/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 42.7/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 43.0/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 43.3/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 43.5/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 43.8/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 44.3/203.1 MB 1.6 MB/s eta 0:01:39
#    -------- ------------------------------- 44.6/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 44.8/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 45.1/203.1 MB 1.6 MB/s eta 0:01:38
#    -------- ------------------------------- 45.4/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 45.9/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 45.9/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 46.4/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 46.7/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 46.9/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 47.2/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 47.4/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 47.4/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 48.0/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 48.2/203.1 MB 1.6 MB/s eta 0:01:37
#    --------- ------------------------------ 48.2/203.1 MB 1.6 MB/s eta 0:01:37
#    --------- ------------------------------ 48.8/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 48.8/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 49.0/203.1 MB 1.6 MB/s eta 0:01:37
#    --------- ------------------------------ 49.3/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 49.5/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 49.5/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 49.5/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 50.1/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 50.1/203.1 MB 1.6 MB/s eta 0:01:38
#    --------- ------------------------------ 50.3/203.1 MB 1.5 MB/s eta 0:01:39
#    --------- ------------------------------ 50.6/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 50.9/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 51.1/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 51.4/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 51.6/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 51.9/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 51.9/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 52.4/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 52.7/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 52.7/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 53.0/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 53.2/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 53.5/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 53.7/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 54.0/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 54.3/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 54.5/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 54.5/203.1 MB 1.5 MB/s eta 0:01:40
#    ---------- ----------------------------- 55.1/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 55.3/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 55.6/203.1 MB 1.5 MB/s eta 0:01:39
#    ---------- ----------------------------- 55.6/203.1 MB 1.5 MB/s eta 0:01:39
#    ----------- ---------------------------- 56.1/203.1 MB 1.5 MB/s eta 0:01:39
#    ----------- ---------------------------- 56.4/203.1 MB 1.5 MB/s eta 0:01:39
#    ----------- ---------------------------- 56.9/203.1 MB 1.5 MB/s eta 0:01:38
#    ----------- ---------------------------- 57.1/203.1 MB 1.5 MB/s eta 0:01:38
#    ----------- ---------------------------- 57.7/203.1 MB 1.5 MB/s eta 0:01:38
#    ----------- ---------------------------- 57.9/203.1 MB 1.5 MB/s eta 0:01:38
#    ----------- ---------------------------- 58.5/203.1 MB 1.5 MB/s eta 0:01:37
#    ----------- ---------------------------- 58.7/203.1 MB 1.5 MB/s eta 0:01:37
#    ----------- ---------------------------- 59.0/203.1 MB 1.5 MB/s eta 0:01:37
#    ----------- ---------------------------- 59.5/203.1 MB 1.5 MB/s eta 0:01:36
#    ----------- ---------------------------- 59.8/203.1 MB 1.5 MB/s eta 0:01:36
#    ----------- ---------------------------- 60.0/203.1 MB 1.5 MB/s eta 0:01:36
#    ----------- ---------------------------- 60.6/203.1 MB 1.5 MB/s eta 0:01:35
#    ----------- ---------------------------- 60.8/203.1 MB 1.5 MB/s eta 0:01:35
#    ------------ --------------------------- 61.1/203.1 MB 1.5 MB/s eta 0:01:35
#    ------------ --------------------------- 61.6/203.1 MB 1.5 MB/s eta 0:01:35
#    ------------ --------------------------- 61.6/203.1 MB 1.5 MB/s eta 0:01:35
#    ------------ --------------------------- 62.1/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------ --------------------------- 62.4/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------ --------------------------- 62.7/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------ --------------------------- 62.9/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 63.2/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 63.7/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 64.0/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 64.2/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 64.5/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 64.7/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 65.0/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 65.3/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 65.5/203.1 MB 1.5 MB/s eta 0:01:33
#    ------------ --------------------------- 65.8/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------ --------------------------- 65.8/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 66.3/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 66.6/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 66.8/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 67.1/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 67.4/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 67.6/203.1 MB 1.5 MB/s eta 0:01:34
#    ------------- -------------------------- 67.9/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 68.2/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 68.4/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 68.7/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 68.9/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 69.2/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 69.2/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 69.7/203.1 MB 1.4 MB/s eta 0:01:33
#    ------------- -------------------------- 70.0/203.1 MB 1.4 MB/s eta 0:01:33
#    ------------- -------------------------- 70.3/203.1 MB 1.4 MB/s eta 0:01:34
#    ------------- -------------------------- 70.5/203.1 MB 1.4 MB/s eta 0:01:33
#    ------------- -------------------------- 70.8/203.1 MB 1.4 MB/s eta 0:01:33
#    ------------- -------------------------- 71.0/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 71.6/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 71.8/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 72.1/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 72.4/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 72.6/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 72.9/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 73.1/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 73.4/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 73.7/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 73.9/203.1 MB 1.4 MB/s eta 0:01:33
#    -------------- ------------------------- 74.4/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 74.7/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 75.0/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 75.2/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 75.5/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 75.5/203.1 MB 1.4 MB/s eta 0:01:32
#    -------------- ------------------------- 75.8/203.1 MB 1.4 MB/s eta 0:01:33
#    --------------- ------------------------ 76.3/203.1 MB 1.4 MB/s eta 0:01:32
#    --------------- ------------------------ 76.5/203.1 MB 1.4 MB/s eta 0:01:32
#    --------------- ------------------------ 76.8/203.1 MB 1.4 MB/s eta 0:01:32
#    --------------- ------------------------ 77.1/203.1 MB 1.4 MB/s eta 0:01:31
#    --------------- ------------------------ 77.3/203.1 MB 1.4 MB/s eta 0:01:31
#    --------------- ------------------------ 77.9/203.1 MB 1.4 MB/s eta 0:01:31
#    --------------- ------------------------ 78.1/203.1 MB 1.4 MB/s eta 0:01:31
#    --------------- ------------------------ 78.4/203.1 MB 1.4 MB/s eta 0:01:31
#    --------------- ------------------------ 78.6/203.1 MB 1.4 MB/s eta 0:01:30
#    --------------- ------------------------ 79.2/203.1 MB 1.4 MB/s eta 0:01:30
#    --------------- ------------------------ 79.4/203.1 MB 1.4 MB/s eta 0:01:30
#    --------------- ------------------------ 79.7/203.1 MB 1.4 MB/s eta 0:01:30
#    --------------- ------------------------ 80.0/203.1 MB 1.4 MB/s eta 0:01:30
#    --------------- ------------------------ 80.5/203.1 MB 1.4 MB/s eta 0:01:29
#    --------------- ------------------------ 80.7/203.1 MB 1.4 MB/s eta 0:01:29
#    --------------- ------------------------ 81.0/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 81.3/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 81.5/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 81.8/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 82.1/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 82.3/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 82.6/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 82.8/203.1 MB 1.4 MB/s eta 0:01:29
#    ---------------- ----------------------- 83.1/203.1 MB 1.4 MB/s eta 0:01:28
#    ---------------- ----------------------- 83.4/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 83.6/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 83.6/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 84.1/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 84.4/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 84.7/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 84.9/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 85.2/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 85.5/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 85.7/203.1 MB 1.4 MB/s eta 0:01:27
#    ---------------- ----------------------- 86.0/203.1 MB 1.4 MB/s eta 0:01:26
#    ---------------- ----------------------- 86.2/203.1 MB 1.4 MB/s eta 0:01:26
#    ----------------- ---------------------- 86.8/203.1 MB 1.4 MB/s eta 0:01:26
#    ----------------- ---------------------- 87.0/203.1 MB 1.4 MB/s eta 0:01:25
#    ----------------- ---------------------- 87.3/203.1 MB 1.4 MB/s eta 0:01:25
#    ----------------- ---------------------- 87.6/203.1 MB 1.4 MB/s eta 0:01:25
#    ----------------- ---------------------- 88.1/203.1 MB 1.4 MB/s eta 0:01:24
#    ----------------- ---------------------- 88.3/203.1 MB 1.4 MB/s eta 0:01:24
#    ----------------- ---------------------- 88.6/203.1 MB 1.4 MB/s eta 0:01:24
#    ----------------- ---------------------- 89.1/203.1 MB 1.4 MB/s eta 0:01:23
#    ----------------- ---------------------- 89.4/203.1 MB 1.4 MB/s eta 0:01:23
#    ----------------- ---------------------- 89.9/203.1 MB 1.4 MB/s eta 0:01:22
#    ----------------- ---------------------- 90.2/203.1 MB 1.4 MB/s eta 0:01:22
#    ----------------- ---------------------- 90.4/203.1 MB 1.4 MB/s eta 0:01:22
#    ----------------- ---------------------- 90.7/203.1 MB 1.4 MB/s eta 0:01:21
#    ----------------- ---------------------- 91.0/203.1 MB 1.4 MB/s eta 0:01:21
#    ----------------- ---------------------- 91.2/203.1 MB 1.4 MB/s eta 0:01:21
#    ------------------ --------------------- 91.5/203.1 MB 1.4 MB/s eta 0:01:20
#    ------------------ --------------------- 91.8/203.1 MB 1.4 MB/s eta 0:01:19
MB/s eta 0:00:27
#    ---------- ----------------------------- 11.3/44.8 MB 1.3 MB/s eta 0:00:27
#    ---------- ----------------------------- 11.5/44.8 MB 1.2 MB/s eta 0:00:27
#    ---------- ----------------------------- 11.8/44.8 MB 1.2 MB/s eta 0:00:27
#    ---------- ----------------------------- 11.8/44.8 MB 1.2 MB/s eta 0:00:27
#    ---------- ----------------------------- 12.1/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 12.3/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 12.6/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 12.6/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 12.8/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 13.1/44.8 MB 1.2 MB/s eta 0:00:27
#    ----------- ---------------------------- 13.4/44.8 MB 1.2 MB/s eta 0:00:27
#    ------------ --------------------------- 13.6/44.8 MB 1.2 MB/s eta 0:00:26
#    ------------ --------------------------- 13.9/44.8 MB 1.2 MB/s eta 0:00:26
#    ------------ --------------------------- 14.2/44.8 MB 1.2 MB/s eta 0:00:26
#    ------------ --------------------------- 14.2/44.8 MB 1.2 MB/s eta 0:00:26
#    ------------ --------------------------- 14.4/44.8 MB 1.2 MB/s eta 0:00:26
#    ------------- -------------------------- 14.9/44.8 MB 1.2 MB/s eta 0:00:25
#    ------------- -------------------------- 15.2/44.8 MB 1.2 MB/s eta 0:00:25
#    ------------- -------------------------- 15.5/44.8 MB 1.2 MB/s eta 0:00:25
#    -------------- ------------------------- 15.7/44.8 MB 1.2 MB/s eta 0:00:24
#    -------------- ------------------------- 16.3/44.8 MB 1.2 MB/s eta 0:00:24
#    -------------- ------------------------- 16.5/44.8 MB 1.2 MB/s eta 0:00:23
#    -------------- ------------------------- 16.8/44.8 MB 1.2 MB/s eta 0:00:23
#    --------------- ------------------------ 17.0/44.8 MB 1.2 MB/s eta 0:00:23
#    --------------- ------------------------ 17.3/44.8 MB 1.2 MB/s eta 0:00:23
#    --------------- ------------------------ 17.8/44.8 MB 1.3 MB/s eta 0:00:22
#    ---------------- ----------------------- 18.1/44.8 MB 1.3 MB/s eta 0:00:22
#    ---------------- ----------------------- 18.4/44.8 MB 1.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 18.6/44.8 MB 1.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 18.9/44.8 MB 1.3 MB/s eta 0:00:21
#    ----------------- ---------------------- 19.1/44.8 MB 1.3 MB/s eta 0:00:21
#    ----------------- ---------------------- 19.4/44.8 MB 1.3 MB/s eta 0:00:20
#    ----------------- ---------------------- 19.7/44.8 MB 1.3 MB/s eta 0:00:20
#    ------------------ --------------------- 20.2/44.8 MB 1.3 MB/s eta 0:00:20
#    ------------------ --------------------- 20.4/44.8 MB 1.3 MB/s eta 0:00:20
#    ------------------ --------------------- 20.7/44.8 MB 1.3 MB/s eta 0:00:19
#    ------------------ --------------------- 21.0/44.8 MB 1.3 MB/s eta 0:00:19
#    ------------------ --------------------- 21.2/44.8 MB 1.3 MB/s eta 0:00:19
#    ------------------- -------------------- 21.5/44.8 MB 1.3 MB/s eta 0:00:19
#    ------------------- -------------------- 21.8/44.8 MB 1.3 MB/s eta 0:00:19
#    ------------------- -------------------- 22.0/44.8 MB 1.3 MB/s eta 0:00:18
#    ------------------- -------------------- 22.3/44.8 MB 1.3 MB/s eta 0:00:18
#    -------------------- ------------------- 22.5/44.8 MB 1.3 MB/s eta 0:00:18
#    -------------------- ------------------- 22.8/44.8 MB 1.3 MB/s eta 0:00:18
#    -------------------- ------------------- 23.1/44.8 MB 1.3 MB/s eta 0:00:17
#    -------------------- ------------------- 23.3/44.8 MB 1.3 MB/s eta 0:00:17
#    --------------------- ------------------ 23.6/44.8 MB 1.3 MB/s eta 0:00:17
#    --------------------- ------------------ 23.9/44.8 MB 1.3 MB/s eta 0:00:17
#    --------------------- ------------------ 24.1/44.8 MB 1.3 MB/s eta 0:00:17
#    --------------------- ------------------ 24.4/44.8 MB 1.3 MB/s eta 0:00:17
#    --------------------- ------------------ 24.4/44.8 MB 1.3 MB/s eta 0:00:17
#    ---------------------- ----------------- 24.6/44.8 MB 1.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 25.2/44.8 MB 1.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 25.4/44.8 MB 1.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 25.7/44.8 MB 1.3 MB/s eta 0:00:15
#    ----------------------- ---------------- 26.0/44.8 MB 1.3 MB/s eta 0:00:15
#    ----------------------- ---------------- 26.2/44.8 MB 1.3 MB/s eta 0:00:15
#    ----------------------- ---------------- 26.5/44.8 MB 1.3 MB/s eta 0:00:15
#    ----------------------- ---------------- 26.7/44.8 MB 1.3 MB/s eta 0:00:15
#    ------------------------ --------------- 27.0/44.8 MB 1.3 MB/s eta 0:00:14
#    ------------------------ --------------- 27.3/44.8 MB 1.3 MB/s eta 0:00:14
#    ------------------------ --------------- 27.5/44.8 MB 1.3 MB/s eta 0:00:14
#    ------------------------- -------------- 28.0/44.8 MB 1.3 MB/s eta 0:00:14
#    ------------------------- -------------- 28.3/44.8 MB 1.3 MB/s eta 0:00:13
#    ------------------------- -------------- 28.6/44.8 MB 1.3 MB/s eta 0:00:13
#    ------------------------- -------------- 28.8/44.8 MB 1.3 MB/s eta 0:00:13
#    ------------------------- -------------- 29.1/44.8 MB 1.3 MB/s eta 0:00:13
#    -------------------------- ------------- 29.4/44.8 MB 1.3 MB/s eta 0:00:12
#    -------------------------- ------------- 29.6/44.8 MB 1.3 MB/s eta 0:00:12
#    -------------------------- ------------- 29.9/44.8 MB 1.3 MB/s eta 0:00:12
#    -------------------------- ------------- 30.1/44.8 MB 1.3 MB/s eta 0:00:12
#    --------------------------- ------------ 30.4/44.8 MB 1.3 MB/s eta 0:00:12
#    --------------------------- ------------ 30.7/44.8 MB 1.3 MB/s eta 0:00:11
#    --------------------------- ------------ 30.9/44.8 MB 1.3 MB/s eta 0:00:11
#    --------------------------- ------------ 31.2/44.8 MB 1.3 MB/s eta 0:00:11
#    ---------------------------- ----------- 31.7/44.8 MB 1.3 MB/s eta 0:00:11
#    ---------------------------- ----------- 32.0/44.8 MB 1.3 MB/s eta 0:00:10
#    ---------------------------- ----------- 32.2/44.8 MB 1.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 32.5/44.8 MB 1.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 33.0/44.8 MB 1.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 33.0/44.8 MB 1.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 33.6/44.8 MB 1.3 MB/s eta 0:00:09
#    ------------------------------ --------- 33.8/44.8 MB 1.3 MB/s eta 0:00:09
#    ------------------------------ --------- 34.1/44.8 MB 1.3 MB/s eta 0:00:09
#    ------------------------------ --------- 34.3/44.8 MB 1.3 MB/s eta 0:00:08
#    ------------------------------ --------- 34.6/44.8 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 34.9/44.8 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 35.1/44.8 MB 1.3 MB/s eta 0:00:08
#    ------------------------------- -------- 35.4/44.8 MB 1.3 MB/s eta 0:00:08
#    -------------------------------- ------- 35.9/44.8 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 36.2/44.8 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 36.4/44.8 MB 1.3 MB/s eta 0:00:07
#    -------------------------------- ------- 36.7/44.8 MB 1.3 MB/s eta 0:00:07
#    --------------------------------- ------ 37.0/44.8 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 37.5/44.8 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 37.7/44.8 MB 1.3 MB/s eta 0:00:06
#    --------------------------------- ------ 38.0/44.8 MB 1.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 38.3/44.8 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.5/44.8 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 38.8/44.8 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 39.1/44.8 MB 1.3 MB/s eta 0:00:05
#    ----------------------------------- ---- 39.3/44.8 MB 1.3 MB/s eta 0:00:05
#    ----------------------------------- ---- 39.6/44.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 39.8/44.8 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 40.1/44.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 40.4/44.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 40.6/44.8 MB 1.3 MB/s eta 0:00:04
#    ------------------------------------ --- 40.9/44.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 41.2/44.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 41.7/44.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 41.7/44.8 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 42.2/44.8 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 42.5/44.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 42.7/44.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.0/44.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.0/44.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.3/44.8 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 43.5/44.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  44.6/44.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 1.3 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.5 MB/s eta 0:00:00
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: nemo-toolkit, wget
#   Building wheel for nemo-toolkit (pyproject.toml): started
#   Building wheel for nemo-toolkit (pyproject.toml): finished with status 'done'
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-2.1.0rc0-py3-none-any.whl size=5020473 sha256=a538b23cefd4ad39697b2fe4d5d2cc1f68554d763610706933bcc571029c17b9
#   Stored in directory: C:\Users\Patrickn\AppData\Local\Temp\pip-ephem-wheel-cache-j8dbr8cg\wheels\c3\4e\45\ab3d29aa73df619f27b371cacf809d5330a18f794879163c1b
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=b24d884ce7d34a27b474c39bb3ede56b82f9f41e76fe1e8667e5844f0bab651e
#   Stored in directory: c:\users\patrickn\appdata\local\pip\cache\wheels\8b\f1\7f\5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built nemo-toolkit wget
# Installing collected packages: wget, text-unidecode, mpmath, wrapt, werkzeug, tqdm, threadpoolctl, tensorboard-data-server, sympy, ruamel.yaml.clib, protobuf, numpy, networkx, markdown, llvmlite, joblib, grpcio, fsspec, filelock, absl-py, torch, tensorboard, scipy, ruamel.yaml, onnx, numba, huggingface_hub, scikit-learn, nemo-toolkit
# Successfully installed absl-py-2.1.0 filelock-3.16.1 fsspec-2024.10.0 grpcio-1.68.0 huggingface_hub-0.26.2 joblib-1.4.2 llvmlite-0.43.0 markdown-3.7 mpmath-1.3.0 nemo-toolkit-2.1.0rc0 networkx-3.4.2 numba-0.60.0 numpy-2.0.2 onnx-1.17.0 protobuf-5.28.3 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.12 scikit-learn-1.5.2 scipy-1.14.1 sympy-1.13.1 tensorboard-2.18.0 tensorboard-data-server-0.7.2 text-unidecode-1.3 threadpoolctl-3.5.0 torch-2.5.1 tqdm-4.67.1 werkzeug-3.1.3 wget-3.2 wrapt-1.17.0
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git 'C:\Users\Patrickn\AppData\Local\Temp\pip-req-build-7a1bo0h3'
#   WARNING: The script tqdm.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script isympy.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe, torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts backend-test-tools.exe, check-model.exe and check-node.exe are installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script huggingface-cli.exe is installed in 'C:\Users\Patrickn\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.10.1 requires astunparse>=1.6.0, which is not installed.
# tensorflow-gpu 2.10.1 requires flatbuffers>=2.0, which is not installed.
# tensorflow-gpu 2.10.1 requires gast<=0.4.0,>=0.2.1, which is not installed.
# tensorflow-gpu 2.10.1 requires google-pasta>=0.1.1, which is not installed.
# tensorflow-gpu 2.10.1 requires h5py>=2.9.0, which is not installed.
# tensorflow-gpu 2.10.1 requires keras<2.11,>=2.10.0, which is not installed.
# tensorflow-gpu 2.10.1 requires keras-preprocessing>=1.1.1, which is not installed.
# tensorflow-gpu 2.10.1 requires libclang>=13.0.0, which is not installed.
# tensorflow-gpu 2.10.1 requires opt-einsum>=2.3.2, which is not installed.
# tensorflow-gpu 2.10.1 requires tensorflow-estimator<2.11,>=2.10.0, which is not installed.
# tensorflow-gpu 2.10.1 requires tensorflow-io-gcs-filesystem>=0.23.1, which is not installed.
# tensorflow-gpu 2.10.1 requires termcolor>=1.1.0, which is not installed.
# tensorflow-gpu 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-gpu 2.10.1 requires tensorboard<2.11,>=2.10, but you have tensorboard 2.18.0 which is incompatible.

# %%
import torch
import librosa
import torchaudio
import nemo.collections.asr as nemo_asr
from ruamel.yaml import YAML
from omegaconf import OmegaConf

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ASR model
def load_asr_model(ckpt_path):
    config_path = 'repo/ASR_for_egyptian_dialect/configs/FC-transducer-inference.yaml'
    yaml = YAML(typ='safe')
    with open(config_path) as f:
        params = yaml.load(f)
    params['model'].pop('test_ds', None)
    conf = OmegaConf.create(params)

    model = nemo_asr.models.EncDecRNNTBPEModel(cfg=conf['model']).to(device)
    model.load_state_dict(torch.load(ckpt_path)['state_dict'])
    model.eval()
    return model

# Function to load audio using librosa
def load_audio(audio_path):
    audio, sr = torchaudio.load(audio_path, normalize=True)   # Ensure correct sample rate
    return audio, sr

# Inference function
def infer(model, audio):
    return model.transcribe([audio])

# Path to your specific WAV file
audio_path = "recorded_audio.wav"

# Load the ASR model
print("Loading ASR model...")
asr_model = load_asr_model("Models/asr_model.ckpt")

# Load the audio using librosa
print(f"Loading audio from {audio_path}...")
audio, sr = load_audio(audio_path)

# Perform inference
print("Starting inference...")
with torch.no_grad():
    transcript = infer(model=asr_model, audio=audio)

# Print or save the result
print(f"Transcript: {transcript[0]}")

# %%
import librosa
def load_audio(audio_path):
    audio, sr = librosa.load(audio_path, sr=16000)  # Ensure correct sample rate
    return audio, sr

audio_path = "recorded_audio.wav"
print(f"Loading audio from {audio_path}...")
audio, sr = load_audio(audio_path)

# %%
import torchaudio

def load_audio(audio_path):
    audio, sr = torchaudio.load(audio_path, normalize=True)  # normalize=True will scale the waveform between -1 and 1
    return audio, sr

# Example usage
audio_path = "recorded_audio.wav"
print(f"Loading audio from {audio_path}...")
audio, sr = load_audio(audio_path)

# Print the shape of the audio tensor and sample rate
print(f"Audio shape: {audio.shape}, Sample rate: {sr}")
# Out:
# Loading audio from recorded_audio.wav...
# Audio shape: torch.Size([2, 441000]), Sample rate: 44100
